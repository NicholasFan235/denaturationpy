# %%
import Bio.PDB as bpdb
import pylab
import numpy as np
import pandas as pd
import scipy.sparse

# %%
kinetic_data = pd.read_pickle('kinetic_data.pkl')
if not 'RCO' in kinetic_data: kinetic_data.insert(8, "RCO", 0, False)
if not 'ACO' in kinetic_data: kinetic_data.insert(9, "ACO", 0, False)
if not 'LRO' in kinetic_data: kinetic_data.insert(10, "LRO", 0, False)
if not 'SRO' in kinetic_data: kinetic_data.insert(11, "SRO", 0, False)
if not 'LocalCO' in kinetic_data: kinetic_data.insert(12, "LocalCO", 0, False)
if not 'NonLocalCO' in kinetic_data: kinetic_data.insert(13, "NonLocalCO", 0, False)
if not 'TCD' in kinetic_data: kinetic_data.insert(14, "TCD", 0, False)
if not 'CC' in kinetic_data: kinetic_data.insert(15, "CC", 0, False)
if not 'N_alpha' in kinetic_data: kinetic_data.insert(16, "N_alpha", 0, False)

"""kinetic_data = kinetic_data[
    kinetic_data['pdb'].isin([
        '1LMB(Chain 3)', '1UBQ', '2PTL(18-77)', '1APS',
        '1CSP', '1TEN', '1SHF(Chain A)', '1PGB', '1PGB(41-56)',
        '1PIN(6-39)', '2PDD', '1IMQ', '1FNF', '1WIT', '1SHG',
        '1SRL', '1PNJ', '1G6P', '1MJC', '1LOP(Chain A)', '1FKB',
        '2CI2', '1URN(Chain A)'])
]#"""
kinetic_data
# Out:
#                                                   name            pdb  \
# 0                          Colicin E7 immunity protein           1AYI
# 1          Telomeric protein DNA-binding domain, human           1BA5
# 2                      Immunoglobulin binding B-domain     1BDD(2-59)
# 3                      16th domain of brain α-spectrin    1CUN(7-112)
# 4                      17th domain of brain α-spectrin  1CUN(113-219)
# 5                             FADD death-domain, human   1E41(93-192)
# 6                               Rap1 myb-domain, human           1FEX
# 7                             Myb transforming protein           1IDY
# 8                          Colicin E9 immunity protein           1IMQ
# 9                                 Trp-Cage Miniprotein           1L2Y
# 10               Lyme disease variable surface antigen   1L8W(29-335)
# 11                                    Lambda repressor  1LMB(Chain 3)
# 12                Acyl-coenzyme A binding protein, cow           1NTI
# 13                                        Protein yjbJ           1RYK
# 14                                   BBA5 mini-protein           1T8J
# 15                15th domain of brain alpha- spectrin           1U5P
# 16                                    Villin Headpiece           1VII
# 17   Dihydrolipolysine acetyltransferase, G. stearo...           1W4G
# 18      Dihydrolipolysine succinyltransferase, E. coli           1W4H
# 19            Pyruvate dehydrogenase E2, P. aerophilum           1W4J
# 20                     de novo designed 3-helix bundle           2A3D
# 21   Peripheral subunit-binding domain, Dihydrolipo...           2PDD
# 22                            E3-binding domain of BBL           2WXC
# 23                 Cold shock protein, B. caldolyticus           1C9O
# 24                     Cold shock protein, B. subtilus           1CSP
# 25                           Formin Binding Protein 28           1E0L
# 26                                        WW prototype           1E0M
# 27                              9th fibronectin domain           1FNF
# 28                     Cold shock protein, T. maritima           1G6P
# 29                                       Hisactophilin           1HCD
# 30                                               sso7d           1JIC
# 31                                     Abp1 SH3 domain           1JO8
# 32             Fibronectin type III WL-12 chitinase A1  1K85(559-644)
# 33           E2 component alpha-ketoacid dehydrogenase           1K8M
# 34                       Yes kinase-associated protein     1K9Q(5-44)
# 35                             Internalin B SH3 domain  1M9S(391-466)
# 36                         Cold shock protein, E. coli           1MJC
# 37                                        Beta-hairpin    1PGB(41-56)
# 38                                               PinWW     1PIN(6-39)
# 39                                      PI3 SH3 domain           1PNJ
# 40                                Oncoprotein p13mtcp1    1QTU(1-109)
# 41                                      Fyn SH3 domain  1SHF(Chain A)
# 42                                 Spectrin SH3 domain           1SHG
# 43                                      Src SH3 domain           1SRL
# 44                       Fibronectin type III tenascin           1TEN
# 45              18th module of muscle protein twitchin           1WIT
# 46                                     Sho1 SH3 domain  2VKN(Chain A)
# 47                                            Symfoil1           3O49
# 48                                           Symfoil4P           3O4D
# 49                                           ThreeFoil           3PG0
# 50                              Muscle acylphosphatase           1APS
# 51                     C-terminal domain of protein L9   1DIV(58-149)
# 52                     N-terminal domain of protein L9     1DIV(1-56)
# 53                                         LysM Domain           1E0G
# 54                               FK506 binding protein           1FKB
# 55                             Apoflavodoxin, Anabaena           1FTG
# 56                                              Tm1083           1J5U
# 57                             Chemotaxis protein CheW           1K0S
# 58                                       Cyclophilin A  1LOP(Chain A)
# 59                               Ribosomal protein L23           1N88
# 60                                               ADAh2           1O6X
# 61                              B1 domain of protein G           1PGB
# 62         Histidine containing phosphocarrier protein           1POH
# 63           C-terminal domain of spore coat protein S   1PRS(91-173)
# 64              N-terminal domain spore coat protein S     1PRS(1-90)
# 65                                  Ras binding domain           1RFA
# 66                                Ribosomal protein S6           1RIS
# 67                                      Src SH2 domain  1SPR(Chain C)
# 68                                           Ubiquitin           1UBQ
# 69                            Spliceosomal protein U1A  1URN(Chain A)
# 70                         Common-type acylphosphatase           2ACY
# 71                            Chymotrypsin inhibitor 2           2CI2
# 72                              B1 domain of Protein L    2PTL(18-77)
# 73                                    Pit1 homeodomain  1AU7(103-160)
# 74                       FKBP-Rapamycin binding domain           1AUE
# 75                              p19ink4d CDK inhibitor           1BD8
# 76                               Engrailed homeodomain           1ENH
# 77              Acyl-coenzyme A binding protein, yeast           1ST7
# 78                               FF domain, human hypa           1UZC
# 79                       Tumour suppressor protein p16    2A5E(9-156)
# 80                               Phage 434 cro protein           2CRO
# 81                                         T4 lysozyme           2LZM
# 82                                          Myotrophin           2MYO
# 83                         Ileal lipid binding protein           1EAL
# 84               Intestinal fatty acid binding protein           1IFC
# 85                                               FGF-1  1JQZ(Chain A)
# 86                 Cellular retinol binding protein II  1OPA(Chain A)
# 87                                             Barnase  1RNB(Chain A)
# 88                                  Titin IG repeat 27           1TIU
# 89                    10th type III fibronectin domain           1TTF
# 90                              Apical domain of GroEL  1AON(191-345)
# 91                        Third PDZ domain from PSD-95           1BFE
# 92                                             Barstar           1BTA
# 93            Cellular retinoic acid binding protein I           1CBI
# 94                             PDZ2 domain from PTP-BL           1GM1
# 95                      Hydrogenase maturation protein           1GXT
# 96                 Indole-3-glycerolphosphate synthase   1IGS(27-248)
# 97                             Staphylococcal nuclease           1JOO
# 98        C-terminal domain of phosphoglycerate kinase  1PHP(176-394)
# 99        N-terminal domain of phosphoglycerate kinase    1PHP(1-175)
# 100                             Trp-Synthase α-subunit  1QOP(Chain A)
# 101                            Dihydrofolate reductase           1RA9
# 102              Cell-cycle regulatory protein p13suc1  1SCE(Chain C)
# 103                                 Carbonic anhydrase  1V9E(Chain A)
# 104                           Ribonuclease H1, E. coli           2RN2
# 105                                         Villin 14T           2VIK
# 106                                Chemotactic protein           3CHY
# 107                        Ribonuclease H1, C. tepidum  3H08(Chain A)
#
#     kinetic_state class pdb_length midpoint log_kf  log_ku       RCO  \
# 0             Two     α         85     1.22   3.13    1.00  0.078630
# 1             Two     α         49     0.69   2.56    0.52  0.085722
# 2             Two     α         58     2.52   5.08    1.82  0.070733
# 3             Two     α        106    -0.87   2.08   -2.61  0.080790
# 4             Two     α        107    -1.48   1.48   -3.39  0.080594
# 5             Two     α        100    -0.26   2.95   -1.30  0.059760
# 6             Two     α         59     1.69   3.56    1.26  0.080263
# 7             Two     α         54     1.35   3.78    0.74  0.076444
# 8             Two     α         85    -0.61   3.17   -0.83  0.095965
# 9             Two     α         20     5.65   5.43    4.99  0.139645
# 10            Two     α        307    -2.04   0.88   -3.68  0.072550
# 11            Two     α         80     2.26   4.52    1.39  0.064007
# 12            Two     α         86    -0.13   3.04   -1.69  0.097647
# 13            Two     α         69     2.78   3.95    1.95  0.088526
# 14            Two     α         23     5.43   5.12    5.73  0.092430
# 15            Two     α        110     1.74   4.78    0.13  0.046440
# 16            Two     α         36     4.60   4.08    2.30  0.085633
# 17            Two     α         45     2.52   4.44    1.30  0.095786
# 18            Two     α         45     4.00   5.11    3.78  0.085957
# 19            Two     α         51     3.26   5.32    2.74  0.080606
# 20            Two     α         73     5.39   5.30    3.30  0.073199
# 21            Two     α         42     4.26   4.26    2.35  0.084817
# 22            Two     α         47     3.47   4.86    2.87  0.073117
# 23            Two     β         66     0.09   3.13   -0.17  0.073281
# 24            Two     β         67     1.17   2.82    1.00  0.129683
# 25            Two     β         37     4.00   4.60    3.73  0.122151
# 26            Two     β         37     3.34   3.87    3.08  0.120203
# 27            Two     β         90    -0.96  -0.39   -1.26  0.036614
# 28            Two     β         66    -1.13   2.74   -1.74  0.136818
# 29            Two     β        117    -2.82   1.35   -4.69  0.082896
# 30            Two     β         62     0.26   3.04   -1.39  0.070359
# 31            Two     β         58    -0.91   1.09   -1.17  0.151221
# 32            Two     β         86    -1.65   0.61   -3.04  0.136731
# 33            Two     β         87    -2.04  -0.39   -3.39  0.140125
# 34            Two     β         40     3.04   3.65    2.91  0.125165
# 35            Two     β         76     0.04   1.74   -0.74  0.141814
# 36            Two     β         69     0.69   2.30    0.61  0.125586
# 37            Two     β         16     5.21   5.21    5.21  0.186705
# 38            Two     β         34     3.95   4.04    1.82  0.144387
# 39            Two     β         84    -2.08  -0.43   -3.17  0.121698
# 40            Two     β        109    -3.69   0.00   -4.78  0.113452
# 41            Two     β         59    -0.87   2.13   -1.87  0.140583
# 42            Two     β         57    -1.61   0.48   -2.08  0.148314
# 43            Two     β         56     0.17   1.91   -0.56  0.150062
# 44            Two     β         89    -1.91   0.48   -3.34  0.140582
# 45            Two     β         93    -2.56   0.17   -3.56  0.162583
# 46            Two     β         66    -0.35   0.92   -1.08  0.159795
# 47            Two     β        123    -3.08   0.74   -3.91  0.096888
# 48            Two     β        123    -4.69   2.13   -5.99  0.102442
# 49            Two     β        140    -7.43  -3.87   -8.95  0.128535
# 50            Two    αβ         98    -3.17  -0.69   -3.91  0.167615
# 51            Two    αβ         92    -1.91   1.43   -3.43  0.109315
# 52            Two    αβ         56     0.83   2.87    0.00  0.099264
# 53            Two    αβ         48     1.61   3.04    1.02  0.152093
# 54            Two    αβ        107    -2.26   0.69   -3.52  0.139347
# 55            Two    αβ        168    -0.09   1.22   -1.17  0.076568
# 56            Two    αβ        123    -0.39   2.97   -2.28  0.119631
# 57            Two    αβ        143    -2.17   3.21   -5.25  0.097805
# 58            Two    αβ        164    -1.30   2.87   -4.52  0.124761
# 59            Two    αβ         96    -1.04   0.87   -1.69  0.111218
# 60            Two    αβ         81     0.65   2.95   -0.17  0.108949
# 61            Two    αβ         56    -0.17   2.74   -0.74  0.135228
# 62            Two    αβ         85    -1.30   1.17   -2.69  0.139906
# 63            Two    αβ         83    -3.52  -0.87   -4.04  0.126705
# 64            Two    αβ         90    -2.00   1.30   -4.08  0.117599
# 65            Two    αβ         78    -0.09   3.65   -1.22  0.127764
# 66            Two    αβ         97    -1.69   2.65   -3.60  0.146558
# 67            Two    αβ        103    -0.61   3.78   -1.52  0.092427
# 68            Two    αβ         76    -0.65   3.17   -2.95  0.117688
# 69            Two    αβ         96    -0.17   2.01   -5.09  0.132565
# 70            Two    αβ         98    -1.91   0.35   -2.82  0.156994
# 71            Two    αβ         64    -1.52   2.52   -4.47  0.119299
# 72            Two    αβ         60    -0.61   1.78   -1.43  0.145383
# 73          Multi     α         58     3.21   4.21    2.08  0.068555
# 74          Multi     α         92    -1.04   2.61   -2.35  0.041402
# 75          Multi     α        156    -0.83   1.26   -1.00  0.041018
# 76          Multi     α         54     3.52   4.56    3.30  0.104689
# 77          Multi     α         86    -0.17   3.69    2.78  0.095321
# 78          Multi     α         69     1.00   3.30    0.61  0.098015
# 79          Multi     α        148     0.17   1.52    0.09  0.045719
# 80          Multi     α         64     0.13   1.61   -0.22  0.087627
# 81          Multi     α        164    -2.48   1.78   -6.08  0.055972
# 82          Multi     α        118    -0.13   2.04   -1.39  0.046267
# 83          Multi     β        127    -1.22   0.56   -2.13  0.096619
# 84          Multi     β        131    -1.22   1.48   -2.00  0.106340
# 85          Multi     β        136    -2.87   0.56   -3.08  0.102975
# 86          Multi     β        133    -2.17   0.61   -4.00  0.109521
# 87          Multi     β        109    -1.87   1.13   -3.95  0.085001
# 88          Multi     β         89    -3.00   1.56   -3.30  0.133509
Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 98         0   -4.09  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 99         0   -3.85  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 100        0   -3.79  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 101        0   -1.72  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 102        0   -6.10  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 103        0  -11.73  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 104        0   -7.17  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 105        0   -5.39  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 106        0   -3.20  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...
# 107        0   -9.42  Garbuzynskiy SO, Ivankov DN, Bogatyreva NS, Fi...

# %%
def calc_residue_dist(residue_one, residue_two) :
    """Returns the C-alpha distance between two residues"""
    diff_vector  = residue_one["CA"].coord - residue_two["CA"].coord
    return np.sqrt(np.sum(diff_vector * diff_vector))

def calc_min_dist(r1, r2):
    m = np.inf
    for a1 in r1.get_atoms():
        if a1.name == 'H': continue
        for a2 in r2.get_atoms():
            if a2.name == 'H': continue
            v = a1.coord - a2.coord
            d = np.sqrt(np.sum(v*v))
            m = min(d, m)
    return m
            

def calc_dist_matrix(chain_one, chain_two, distance_metric) :
    """Returns a matrix of C-alpha distances between two chains"""
    answer = np.zeros((len(chain_one), len(chain_two)), float)
    for row, residue_one in enumerate(chain_one) :
        for col, residue_two in enumerate(chain_two) :
            answer[row, col] = distance_metric(residue_one, residue_two)
    return answer

def calc_atom_dist_matrix(r1, r2):
    matrix = np.zeros((len(list(r1.get_atoms())), len(list(r2.get_atoms()))))
    for i, a1 in enumerate(r1.get_atoms()):
        for j, a2 in enumerate(r2.get_atoms()):
            if a1.name == 'H' or a2.name == 'H': matrix[i,j] = np.nan
            v = a1.coord - a2.coord
            matrix[i,j] = np.sqrt(np.sum(v*v))
    return matrix

# %%
R_cutoff = 6.0

'''
ca_dist_matricies = {}
dist_matricies = {}
models = {}

for index, entry in kinetic_data.iterrows():
    struct = bpdb.PDBParser().get_structure(entry.pdb[:4], f'pdb_files/{entry.pdb}.pdb')
    model = struct[0]

    dist_matrix = calc_dist_matrix(list(struct.get_residues()), list(struct.get_residues()), calc_min_dist)
    dist_matricies[entry.pdb] = dist_matrix

    ca_dist_matrix = calc_dist_matrix(list(struct.get_residues()), list(struct.get_residues()), calc_residue_dist)
    ca_dist_matricies[entry.pdb] = ca_dist_matrix
    models[entry.pdb] = model
#'''
# Out:
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 697
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 473
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 469
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 872
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 847
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 804
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 472
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 461
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 676
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 157
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1836
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 673
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 701
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 590
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 188
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1710
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 298
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 353
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 341
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 371
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 575
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 326
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 355
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1042
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 524
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 312
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 310
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 2823
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 531
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 960
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 496
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 476
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 595
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 694
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 334
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 622
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 517
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 135
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 288
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 684
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 902
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 481
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 475
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 455
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 710
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 709
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 546
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 959
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 964
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1083
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 778
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 706
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 441
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 385
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 835
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1329
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1068
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1195
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1281
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 762
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 652
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 439
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 643
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 650
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 683
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 625
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 820
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 837
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 605
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 781
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 787
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 524
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 466
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 494
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1591
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1171
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 470
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 704
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 573
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1113
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 524
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1312
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 905
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 994
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1060
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1140
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1090
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 876
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 691
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 705
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1168
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 835
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 723
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 2178
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 690
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 717
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1792
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1184
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1648
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1367
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 2004
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1271
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 932
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 2057
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1241
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1000
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 982
#   warnings.warn(
# /home/sabsr3/.local/lib/python3.8/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'END' at line 1101
#   warnings.warn(

# %% [markdown]
# ## Calculate RCO and ACO

# %%
R_cutoff = 6.0

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = dist_matricies[entry.pdb]

    RCO_tmp = 0 # Non-Normalized RCO
    N = 0
    for i, r1 in enumerate(list(model.get_residues())):
        for j, r2 in enumerate(list(model.get_residues())):
            if i>=j: continue
            if dist_matrix[i][j] > R_cutoff: continue
            atom_dist_matrix = calc_atom_dist_matrix(r1, r2)

            n = np.sum(np.triu(atom_dist_matrix <= R_cutoff))
            N += n
            RCO_tmp += abs(j-i) * n
    RCO = RCO_tmp/(N*dist_matrix.shape[0])
    ACO = RCO_tmp/N
    kinetic_data.loc[index, 'RCO'] = RCO
    kinetic_data.loc[index, 'ACO'] = ACO

# %% [markdown]
# ## Calculate LRO

# %%
R_cutoff = 8.0

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = ca_dist_matricies[entry.pdb]

    LRO_tmp = 0 # Non-Normalized RCO
    N = 0
    for i in range(dist_matrix.shape[0]):
        for j in range(i+1, dist_matrix.shape[1]):
            if dist_matrix[i][j] > R_cutoff: continue
            N += 1
            LRO_tmp += 1 if abs(j-i) > 12 else 0
    LRO = LRO_tmp / dist_matrix.shape[0]
    kinetic_data.loc[index, 'LRO'] = LRO

# %% [markdown]
# ## Calculate SRO

# %%
R_cutoff = 8.0
Smax = 6

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = dist_matricies[entry.pdb]

    SRO_tmp = 0 # Non-Normalized RCO
    N = 0
    for i, r1 in enumerate(list(model.get_residues())):
        for j, r2 in enumerate(list(model.get_residues())):
            if i>=j: continue
            if dist_matrix[i][j] > R_cutoff: continue
            if abs(i-j) > Smax: continue
            atom_dist_matrix = calc_atom_dist_matrix(r1, r2)

            n = np.sum(np.triu(atom_dist_matrix <= R_cutoff))
            
            N += n
            SRO_tmp += n
    SRO = SRO_tmp / dist_matrix.shape[0]
    kinetic_data.loc[index, 'SRO'] = SRO

# %% [markdown]
# ## Calculate LocalCO

# %%
R_cutoff = 8.0
Smax = 6

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = dist_matricies[entry.pdb]
    
    LCO_temp = 0 # Non-Normalized RCO
    N = 0
    for i, r1 in enumerate(list(model.get_residues())):
        for j, r2 in enumerate(list(model.get_residues())):
            if i>=j: continue
            if dist_matrix[i][j] > R_cutoff: continue
            if abs(i-j) > Smax: continue
            atom_dist_matrix = calc_atom_dist_matrix(r1, r2)

            n = np.sum(np.triu(atom_dist_matrix <= R_cutoff))

            N += n
            LCO_temp += abs(j-i) * n
    LCO = LCO_temp / N
    kinetic_data.loc[index, 'LocalCO'] = LCO

# %% [markdown]
# ## Calculate NonLocal Contact Order

# %%
R_cutoff = 8.0
Smin = 12

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = dist_matricies[entry.pdb]

    NLCO_temp = 0 # Non-Normalized RCO
    N = 0
    for i, r1 in enumerate(list(model.get_residues())):
        for j, r2 in enumerate(list(model.get_residues())):
            if i>=j: continue
            if dist_matrix[i][j] > R_cutoff: continue
            if abs(i-j) < Smin: continue
            atom_dist_matrix = calc_atom_dist_matrix(r1, r2)

            n = np.sum(np.triu(atom_dist_matrix <= R_cutoff))

            N += n
            NLCO_temp += abs(j-i) * n
    NLCO = NLCO_temp / N
    kinetic_data.loc[index, 'NonLocalCO'] = NLCO

# %% [markdown]
# ## Calculate Total Contact Distance

# %%
R_cutoff = 6.0
lcut = 2

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = dist_matricies[entry.pdb]

    TCD_temp = 0 # Non-Normalized RCO
    N = 0
    for i, r1 in enumerate(list(model.get_residues())):
        for j, r2 in enumerate(list(model.get_residues())):
            if i>=j: continue
            if dist_matrix[i][j] > R_cutoff: continue
            if abs(j-i) <= lcut: continue

            atom_dist_matrix = calc_atom_dist_matrix(r1, r2)

            n = np.sum(np.triu(atom_dist_matrix <= R_cutoff))
            
            N += 1
            TCD_temp += abs(j-i)
    TCD = TCD_temp / (dist_matrix.shape[0] * dist_matrix.shape[0])
    kinetic_data.loc[index, 'TCD'] = TCD

# %% [markdown]
# ## Clustering Coefficient

# %%
R_cutoff = 4.5

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = dist_matricies[entry.pdb]

    CC_temp = np.zeros(dist_matrix.shape[0]) # Non-Normalized CC
    for i, r1 in enumerate(list(model.get_residues())):
        Nc = 0
        for j, r2 in enumerate(list(model.get_residues())):
            if i==j: continue
            if abs(i-j) > 1 and dist_matrix[i][j] > R_cutoff: continue
            if dist_matrix[i][j] <= R_cutoff: Nc += 1
            for k, r3 in enumerate(list(model.get_residues())):
                if j >= k: continue
                if i==k: continue
                if dist_matrix[j][k] > R_cutoff: continue
                if abs(i-k) > 1 and dist_matrix[i][k] > R_cutoff: continue

                CC_temp[i] += 1
        #print(f'{CC_temp[i]}, {Nc}')
        if (CC_temp[i] > 0):
            CC_temp[i] /= Nc*(Nc-1)/2
    CC = np.mean(CC_temp)
    kinetic_data.loc[index, 'CC'] = CC

# %% [markdown]
# ## Geometric Contact Number

# %%
from scipy.spatial import Delaunay
from scipy.spatial import Voronoi
from scipy.spatial import ConvexHull
import shapely
R_cutoff = 6.5

for index, entry in kinetic_data.iterrows():
    model = models[entry.pdb]
    dist_matrix = ca_dist_matricies[entry.pdb]
    residues = list(model.get_residues())

    points = np.zeros((len(residues), 3))
    for i, residue in enumerate(residues):
        for a in residue.get_atoms():
            if a.name == 'CA': points[i] = a.coord
    tri = Delaunay(points, qhull_options='QJ')
    
    contacts = set()
    for simplex in tri.simplices:
        for i in range(4):
            for j in range(i+1, 4):
                r1 = simplex[i]; r2 = simplex[j]
                if dist_matrix[r1][r2] > R_cutoff or abs(r1-r2) < 5: continue
                contacts.add(r1); contacts.add(r2)
    #kinetic_data.loc[index, 'N_alpha'] = len(contacts)

# %%
pd.set_option('display.max_rows', None)
#kinetic_data[['pdb', 'pdb_length', 'RCO', 'ACO', 'LRO', 'SRO', 'LocalCO', 'NonLocalCO', 'TCD', 'CC', 'log_kf', 'log_ku', 'deltaG']].sort_values('pdb')
kinetic_data[['pdb', 'pdb_length', 'N_alpha', 'log_kf', 'log_ku', 'deltaG']].sort_values('pdb')
# Out:
#                pdb pdb_length  N_alpha log_kf  log_ku  deltaG
# 90   1AON(191-345)        155        0  -0.65   -2.48   -2.49
# 50            1APS         98        0  -0.69   -3.91   -4.38
# 73   1AU7(103-160)         58        0   4.21    2.08   -2.90
# 74            1AUE         92        0   2.61   -2.35   -6.75
# 0             1AYI         85        0   3.13    1.00   -2.90
# 1             1BA5         49        0   2.56    0.52   -2.78
# 75            1BD8        156        0   1.26   -1.00   -3.08
# 2       1BDD(2-59)         58        0   5.08    1.82   -4.44
# 91            1BFE        110        0   1.30   -1.48   -3.79
# 92            1BTA         89        0   1.48   -1.17   -3.61
# 23            1C9O         66        0   3.13   -0.17   -4.50
# 93            1CBI        136        0  -1.39   -4.26   -3.91
# 24            1CSP         67        0   2.82    1.00   -2.49
# 4    1CUN(113-219)        107        0   1.48   -3.39   -6.64
# 3      1CUN(7-112)        106        0   2.08   -2.61   -6.40
# 52      1DIV(1-56)         56        0   2.87    0.00   -3.90
# 51    1DIV(58-149)         92        0   1.43   -3.43   -6.64
# 53            1E0G         48        0   3.04    1.02   -2.75
# 25            1E0L         37        0   4.60    3.73   -1.18
# 26            1E0M         37        0   3.87    3.08   -1.07
# 5     1E41(93-192)        100        0   2.95   -1.30   -5.81
# 83            1EAL        127        0   0.56   -2.13   -3.67
# 76            1ENH         54        0   4.56    3.30   -1.72
# 6             1FEX         59        0   3.56    1.26   -3.14
# 54            1FKB        107        0   0.69   -3.52   -5.75
# 27            1FNF         90        0  -0.39   -1.26   -1.18
# 55            1FTG        168        0   1.22   -1.17   -3.26
# 28            1G6P         66        0   2.74   -1.74   -6.10
# 94            1GM1         94        0   0.35   -1.00   -1.84
# 95            1GXT         88        0   1.91   -2.95   -6.64
# 29            1HCD        117        0   1.35   -4.69   -8.23
# 7             1IDY         54        0   3.78    0.74   -4.15
# 84            1IFC        131        0   1.48   -2.00   -4.74
# 96    1IGS(27-248)        222        0  -2.00   -5.91   -5.33
# 8             1IMQ         85        0   3.17   -0.83   -5.45
# 56            1J5U        123        0   2.97   -2.28   -7.17
# 30            1JIC         62        0   3.04   -1.39   -6.04
# 31            1JO8         58        0   1.09   -1.17   -3.08
# 97            1JOO        149        0   1.00   -3.65   -6.34
# 85   1JQZ(Chain A)        136        0   0.56   -3.08   -4.98
# 57            1K0S        143        0   3.21   -5.25  -11.55
# 32   1K85(559-644)         86        0   0.61   -3.04   -4.98
# 33            1K8M         87        0  -0.39   -3.39   -4.09
# 34      1K9Q(5-44)         40        0   3.65    2.91   -1.01
# 9             1L2Y         20        0   5.43    4.99   -0.59
# 10    1L8W(29-335)        307        0   0.88   -3.68   -6.22
# 11   1LMB(Chain 3)         80        0   4.52    1.39   -4.27
# 58   1LOP(Chain A)        164        0   2.87   -4.52  -10.07
# 35   1M9S(391-466)         76        0   1.74   -0.74   -3.38
# 36            1MJC         69        0   2.30    0.61   -2.31
# 59            1N88         96        0   0.87   -1.69   -3.50
# 12            1NTI         86        0   3.04   -1.69   -6.46
# 60            1O6X         81        0   2.95   -0.17   -4.27
# 86   1OPA(Chain A)        133        0   0.61   -4.00   -6.28
# 61            1PGB         56        0   2.74   -0.74   -4.74
# 37     1PGB(41-56)         16        0   5.21    5.21    0.00
# 99     1PHP(1-175)        175        0   1.00   -1.82   -3.85
# 98   1PHP(176-394)        219        0  -1.69   -4.69   -4.09
# 38      1PIN(6-39)         34        0   4.04    1.82   -3.02
# 39            1PNJ         84        0  -0.43   -3.17   -3.73
# 62            1POH         85        0   1.17   -2.69   -5.27
# 64      1PRS(1-90)         90        0   1.30   -4.08   -7.35
# 63    1PRS(91-173)         83        0  -0.87   -4.04   -4.32
# 100  1QOP(Chain A)        265        0  -1.09   -3.87   -3.79
# 40     1QTU(1-109)        109        0   0.00   -4.78   -6.52
# 101           1RA9        159        0  -1.39   -2.65   -1.72
# 65            1RFA         78        0   3.65   -1.22   -6.64
# 66            1RIS         97        0   2.65   -3.60   -8.53
# 87   1RNB(Chain A)        109        0   1.13   -3.95   -6.93
# 13            1RYK         69        0   3.95    1.95   -2.73
# 102  1SCE(Chain C)         97        0   1.82   -2.65   -6.10
# 41   1SHF(Chain A)         59        0   2.13   -1.87   -5.45
# 42            1SHG         57        0   0.48   -2.08   -3.50
# 67   1SPR(Chain C)        103        0   3.78   -1.52   -7.23
# 43            1SRL         56        0   1.91   -0.56   -3.38
# 77            1ST7         86        0   3.69    2.78   -1.24
# 14            1T8J         23        0   5.12    5.73    0.83
# 44            1TEN         89        0   0.48   -3.34   -5.21
# 88            1TIU         89        0   1.56   -3.30   -6.64
# 89            1TTF         94        0   2.39   -3.65   -8.23
# 15            1U5P        110        0   4.78    0.13   -6.34
# 68            1UBQ         76        0   3.17   -2.95   -8.35
# 69   1URN(Chain A)         96        0   2.01   -5.09   -9.68
# 78            1UZC         69        0   3.30    0.61   -3.67
# 103  1V9E(Chain A)        259        0  -1.82  -10.42  -11.73
# 16            1VII         36        0   4.08    2.30   -2.43
# 17            1W4G         45        0   4.44    1.30   -4.28
# 18            1W4H         45        0   5.11    3.78   -1.82
# 19            1W4J         51        0   5.32    2.74   -3.52
# 45            1WIT         93        0   0.17   -3.56   -5.09
# 20            2A3D         73        0   5.30    3.30   -2.73
# 79     2A5E(9-156)        148        0   1.52    0.09   -1.95
# 70            2ACY         98        0   0.35   -2.82   -4.32
# 71            2CI2         64        0   2.52   -4.47   -9.54
# 80            2CRO         64        0   1.61   -0.22   -2.49
# 81            2LZM        164        0   1.78   -6.08  -10.72
# 82            2MYO        118        0   2.04   -1.39   -4.68
# 21            2PDD         42        0   4.26    2.35   -2.61
# 72     2PTL(18-77)         60        0   1.78   -1.43   -4.38
# 104           2RN2        155        0   0.04   -5.21   -7.17
# 105           2VIK        126        0   2.17   -1.78   -5.39
# 46   2VKN(Chain A)         66        0   0.92   -1.08   -2.73
# 22            2WXC         47        0   4.86    2.87   -2.73
# 106           3CHY        128        0   0.43   -1.91   -3.20
# 107  3H08(Chain A)        139        0   0.83   -6.08   -9.42
# 47            3O49        123        0   0.74   -3.91   -6.34
# 48            3O4D        123        0   2.13   -5.99  -11.08
# 49            3PG0        140        0  -3.87   -8.95   -6.93

# %%
kinetic_data.to_pickle('kinetic_data_co.pkl')
